# %% [markdown]
# # Задача:
# Взять топ 150 стран по объёму импорта и зеркального импорта товара в 2019 году, Россию туда добавить в любом случае.
#
# Для каждого месяца с 2015 по 2023 год должна быть информация - страна импортёр, страна из которой был ввезён импорт, объёмы физические и стоимостные для каждой комбинации

# %% [markdown]
# # Импорт модулей

# %%
import time
import os
import pandas as pd
import requests

# %% [markdown]
# # Коды UN-49M
#
# Это коды соответствия названия страны/обьединения и их кода

# %%
URL = 'https://comtradeapi.un.org/files/v1/app/reference/Reporters.json'

response = requests.get(URL)
data = response.json()

m49codeToName = dict()

for country in data['results']:
    reporterCode = country['id']
    name = country['text']
    isGroup = country['isGroup']

    if not isGroup:
        m49codeToName[reporterCode] = name

# %% [markdown]
# для примера, код Российской федерации - 643

# %%
m49codeToName[643]
# Out:
# 'Russian Federation'

# %% [markdown]
# # Топ 150 стран по обьему импорта бензина в 2019 году
#
# Получим список стран для которых будем собирать статистику. 2019 год взят за основу
#
# Определимся с **hs_code** - кодом товара, по которому будем собирать статистику и зеркальную статистику

# %%
# 271019: нефтепродукты: средние и тяжелые дистилляты – дизельное топливо, керосин, мазут
hs_code = 271019

# %%
# эти ключи регулярно обновляются и удаляются, поэтому не страшно их выкладывать
PRIMARY_KEY = '9f1492872e0c48e4849fe94ab8cd1332'

# %%
typeCode = 'C' # Товары
freqCode = 'A' # Данные по годам
clCode = 'HS'  

URL = f'https://comtradeapi.un.org/data/v1/get/{typeCode}/{freqCode}/{clCode}' 

params = {
    'subscription-key': PRIMARY_KEY, # Ключ доступа к API Comtrade
    'partnerCode':      0,           # Код UN M49 для всего мира
    'period':           2019,
    'flowCode':         'M',         # Импорт
    'cmdCode':          hs_code      #
}

# %%
response = requests.get(URL, params)

response_data = response.json()['data']
df = pd.json_normalize(response_data)

df['Country'] = df.reporterCode.apply(lambda key: m49codeToName.get(key, ''))

# %%
top150 = df.sort_values(by='primaryValue', ascending=False)\
    .drop_duplicates(subset=['reporterCode'])\
    [['Country', 'reporterCode', 'primaryValue']]\
    .reset_index(drop=True)\
    .head(150)

# %%
top150.head(10)
# Out:
#                 Country  reporterCode  primaryValue
# 0                   USA           842  3.631031e+10
# 1             Singapore           702  3.196973e+10
# 2                France           251  2.028984e+10
# 3               Germany           276  1.743834e+10
# 4        United Kingdom           826  1.648988e+10
# 5           Netherlands           528  1.628514e+10
# 6             Australia            36  1.467114e+10
# 7                 China           156  1.279018e+10
# 8                Mexico           484  1.219187e+10
# 9  China, Hong Kong SAR           344  1.085113e+10

# %% [markdown]
# ### Проверяем что там есть РФ

# %%
top150[top150.reporterCode == 643]
# Out:
#                Country  reporterCode  primaryValue
# 77  Russian Federation           643  8.342934e+08

# %% [markdown]
# # Создаем список стран

# %%
CountryID = list(top150.reporterCode)

# %%
type(CountryID[0])
# Out:
# int

# %% [markdown]
# # Соберем статистику импорта
#
# Для каждого месяца с 2015 по 2023 год должна быть информация - страна Экспортер, страна в которую был ввезён экспорт, объёмы физические и стоимостные для каждой комбинации
#
# По скольку Comtrade API блокирует запросы которые поступают чаще, чем раз в 10 секунд, то все данные собираются синхронно
#
# *Для асинхронной работы можно получить специальный доступ у них на сайте*

# %%
min_year = 2015
max_year = 2023

years = range(min_year, max_year + 1)
months = [f"{month:02}" for month in range(1, 12 + 1)]

# %% [markdown]
# ### сформируем запрос
#
# он будет немного отличаться, чтобы не забывать его структуру, дублирую

# %%
typeCode = 'C' # Товары
freqCode = 'M' # Данные по месяцам
clCode = 'HS'  # Тип товара 

URL = f'https://comtradeapi.un.org/data/v1/get/{typeCode}/{freqCode}/{clCode}' 

params = {
    'subscription-key': PRIMARY_KEY, # Subscription key 
    'flowCode':         'X',         # Export
    'cmdCode':          hs_code,     #
    'reporterCode':     ','.join(map(str, CountryID))
}

# %%
def pull_data(params):
    """получение pd.DataFrame по запросу Comtrade API"""
    
    response = requests.get(URL, params)

    try:
        response_data = response.json()['data']
        df = pd.json_normalize(response_data)
    except Exception as exc:
        raise Exception(f'cant normalize data: {exc}, response: {response.json()}')
    return df

# %% [markdown]
# # Сформируем модель получаемых данных
#
# Данные будут сохраняться в датафрейм со следующими столбцами:
# - period: временной промежуток времени данной статистики
# - reporterCode: код страны, из которой проводился экспорт
# - primaryValue: стоимость поставки (долл. США)
# - netWgt: физический обьем

# %%
data = pd.DataFrame({'period': [], 'reporterCode': [], 'primaryValue': [], 'netWgt': []})

# %% [markdown]
# # Парсинг данных

# %%
for i, year in enumerate(years):
    period = ','.join(str(year) + str(month) for month in months)
    params['period'] = period
    response = requests.get(URL, params)    
    
    try:
        response_data = response.json()['data']
        df = pd.json_normalize(response_data)

    except Exception as exc:
        print(f'\t\tPULLING STOPPED\n\nPulling stopped with exception: {exc}\n\nData saved to ./ABORTED DATA: {hash(period)}.pkl')
        data.to_pickle(f'ABORTED DATA: {hash(period)}.pkl')
        break
    
    periods = df['period'].unique()
    
    for period_ in periods:
        for reporterCode in CountryID:
            filtered_df = df[(df['reporterCode'] == reporterCode) & (df['period'] == period_)]
            
            partners = list(filtered_df['partnerCode'])
            wgts = list(filtered_df['netWgt'])
            values = list(filtered_df['primaryValue'])
    
            primaryValues = {country: value for country, value in zip(partners, values)}
            netWgts = {country: weight for country, weight in zip(partners, wgts)}
    
            row = pd.DataFrame({'period': [period_], 'reporterCode': [reporterCode], 'primaryValue': [primaryValues], 'netWgt': [netWgts]})
            data = pd.concat([data, row])

    print(f'{(i + 1) /  9 * 100:0.2f}%\t{year = }')
# Out:
# 11.11%	year = 2015
# 22.22%	year = 2016
# 33.33%	year = 2017
# 44.44%	year = 2018
# 55.56%	year = 2019
# 66.67%	year = 2020
# 77.78%	year = 2021
# 88.89%	year = 2022
# 100.00%	year = 2023

# %%
data.period.unique()
# Out:
# array(['201501', '201502', '201503', '201504', '201505', '201506',
#        '201507', '201508', '201509', '201510', '201511', '201601',
#        '201602', '201603', '201604', '201605', '201606', '201607',
#        '201608', '201609', '201610', '201701', '201702', '201703',
#        '201704', '201705', '201706', '201707', '201708', '201801',
#        '201802', '201803', '201804', '201805', '201806', '201807',
#        '201901', '201902', '201903', '201904', '201905', '201906',
#        '201907', '202001', '202002', '202003', '202004', '202005',
#        '202006', '202007', '202008', '202101', '202102', '202103',
#        '202104', '202105', '202106', '202107', '202108', '202201',
#        '202202', '202203', '202204', '202205', '202206', '202207',
#        '202301', '202302', '202303', '202304', '202305', '202306',
#        '202307'], dtype=object)

# %%
data.dropna(subset=['reporterCode'], inplace=True)

# %%
data.to_csv(f'graph data imp - {hs_code}.csv')

# %%
data = pd.read_csv(f'graph data imp - {hs_code}.csv', index_col='Unnamed: 0')

# %%
data
# Out:
#     period  reporterCode                                       primaryValue  \
# 0   201501         842.0  {124: 413074932.0, 484: 562456657.0, 826: 1478...
# 0   201501         702.0  {430: 9.72, 0: 2432203650.161, 360: 141837375....
# 0   201501         251.0  {705: 18168329.505, 703: 189945.245, 100: 1011...
# 0   201501         276.0  {842: 1277.148, 699: 363.737, 490: 1622493.805...
# 0   201501         826.0  {0: 380702328.349, 40: 64374.634, 348: 65099.6...
# ..     ...           ...                                                ...
# 0   202307         384.0                                                 {}
# 0   202307         662.0                                                 {}
# 0   202307         308.0                         {0: 1640.37, 780: 1640.37}
# 0   202307         140.0                                                 {}
# 0   202307         690.0                                                 {}
#
#                                                netWgt
# 0   {124: 0.0, 484: 0.0, 826: 0.0, 156: 0.0, 392: ...
# 0   {430: 0.0, 0: 0.0, 360: 240826090.0, 31: 17430...
# 0   {705: 33090308.0, 703: 82427.0, 100: 63437.0, ...
# 0   {842: 716.0, 699: 13.0, 490: 527969.0, 579: 70...
# 0   {0: 890924514.0, 40: 20444.0, 348: 17766.0, 30...
# ..                                                ...
# 0                                                  {}
# 0                                                  {}
# 0                                {0: 50.0, 780: 50.0}
# 0                                                  {}
# 0                                                  {}
#
# [10950 rows x 4 columns]

# %% [markdown]
# # Зеркальная статистика

# %%
typeCode = 'C' # Товары
freqCode = 'M' # Данные по месяцам
clCode = 'HS'  #

URL = f'https://comtradeapi.un.org/data/v1/get/{typeCode}/{freqCode}/{clCode}' 

params = {
    'subscription-key': PRIMARY_KEY, # Subscription key
    'flowCode':         'X',         # Export
    'cmdCode':          hs_code,     #
    'partnerCode':      None,
    'reporterCode':     ','.join(map(str, CountryID))
}

# %%
def pull_data(params):    
    response = requests.get(URL, params)

    response_data = response.json()['data']
    
    df = pd.json_normalize(response_data)
    
    return df

# %% [markdown]
# ## Инициализируем датафрейм
#
# Заполним периоды и коды репортеров, т.к. эти данные статические
#
# зеркальную статистсику оставим пустыми значениями,так понятней сколько собрали и будет проще заполнять пропуски

# %%
mirror_data = pd.DataFrame({
        'period': [f'{year}{month}' for year in years for _ in CountryID for month in months],
        'reporterCode': [ceporterCode for year in years for ceporterCode in CountryID for month in months],
        'mirrorPrimaryValue': [None for year in years for ceporterCode in CountryID for month in months],
        'mirrorNetWgt': [None for year in years for ceporterCode in CountryID for month in months]
    })

# %%
# Если уже сохраняли результат
# mirror_data = pd.read_csv(f'graph data mirrored imp - {hs_code}.csv', index_col='Unnamed: 0')
# mirror_data.period = mirror_data.period.astype('str')

# %%
mirror_data.head(3)
# Out:
#    period  reporterCode                                 mirrorPrimaryValue  \
# 0  201501           842  {32: 20.0, 36: 14213.961, 40: 6345.066, 56: 47...
# 1  201502           842  {352: 144687.791, 360: 2780.0, 372: 10427.245,...
# 2  201503           842  {604: 9238106.87, 579: 22806402.843, 191: 3798...
#
#                                         mirrorNetWgt
# 0  {32: 31.2, 36: 0.0, 40: 0.0, 56: 121257385.254...
# 1  {352: 203952.0, 360: 2813.176, 372: 5407.426, ...
# 2  {604: 13515588.0, 579: 54169094.0, 191: 1002.0...

# %%
min_year = 2015
max_year = 2023

years = range(min_year, max_year + 1)

months = [f"{month:02}" for month in range(1, 12 + 1)]

# %%
def chunk_array(arr):
    """
    У Comtrade API есть ограничение, в запросе должно быть 
    не более 12 периодов. Эта функция делит все периоды на
    чанки по 12 частей
    """
    chunks = list()
    
    for i in range(0, len(arr), 12):
        chunks.append(list(arr[i:min(i + 12, len(arr))]))
    
    return chunks

# %% [markdown]
# # Заполняем значения

# %%
null_data_index = mirror_data[mirror_data.mirrorPrimaryValue.isna()].index

while len(null_data_index := mirror_data[mirror_data.mirrorPrimaryValue.isna()].index) > 0:
    print(f'Total null values: {len(null_data_index)}')
    
    reporter_code = mirror_data[mirror_data.mirrorPrimaryValue.isna()]['reporterCode'].iloc[0]
    periods_chunks = chunk_array(mirror_data[(mirror_data.reporterCode == reporter_code) & (mirror_data.mirrorPrimaryValue.isna())].period.unique())

    for periods in periods_chunks:
        send_request_time = time.time()
        
        params['period'] = ','.join(periods)
        params['partnerCode'] = reporter_code

        print(f'\t-> send request\t\t{reporter_code = }\t{periods[0]} - {periods[-1]}')

        try:
            response = requests.get(URL, params, timeout=60)    
        
        except Exception:
            continue

        get_response_time = time.time()

        if response.status_code == 403:
            params['subscription-key'] = input('Enter new subscription key: ')
            continue
        try:
            response_data = response.json()['data']
            df = pd.json_normalize(response_data)
    
        except Exception as exc:
            print(response.json())
            continue
    
        d_time = get_response_time - send_request_time
        print(f'\t<- response handled:\t{df.shape = }\td_time:{d_time:0.2f}')
        
        # Нужно ждать между запросами хотя бы 10 секунд.
        # Если мы получали ответ больше 10 секунд, то сразу отправляем новый
        time.sleep(max(0, 10 - d_time + 1))       
        
        for period in periods:
            condition = (mirror_data.period == period) & (mirror_data.reporterCode == reporter_code)
            
            try:
                filtered_df = df[df['period'] == period]
                
                reporters = list(filtered_df['reporterCode'])
                m_values = list(filtered_df['primaryValue'])
                m_wgts = list(filtered_df['netWgt'])

                mirror_data.loc[condition, 'mirrorPrimaryValue'] = str({country: value for country, value in zip(reporters, m_values)})
                mirror_data.loc[condition, 'mirrorNetWgt'] = str({country: weight for country, weight in zip(reporters, m_wgts)})
            
            except:
                mirror_data.loc[condition, 'mirrorPrimaryValue'] = str({})
                mirror_data.loc[condition, 'mirrorNetWgt'] = str({})

            null_data_index = mirror_data[mirror_data.mirrorPrimaryValue.isna()].index
# Out:
# Total null values: 7956
# 	-> send request		reporter_code = 70	201501 - 201512
# 	<- response handled:	df.shape = (517, 47)	d_time:5.90
# 	-> send request		reporter_code = 70	201601 - 201612
# 	<- response handled:	df.shape = (581, 47)	d_time:5.91
# 	-> send request		reporter_code = 70	201701 - 201712
# 	<- response handled:	df.shape = (773, 47)	d_time:5.72
# 	-> send request		reporter_code = 70	201801 - 201812
# 	<- response handled:	df.shape = (802, 47)	d_time:5.90
# 	-> send request		reporter_code = 70	201901 - 201912
# 	<- response handled:	df.shape = (868, 47)	d_time:7.04
# 	-> send request		reporter_code = 70	202001 - 202012
# 	<- response handled:	df.shape = (755, 47)	d_time:6.66
# 	-> send request		reporter_code = 70	202101 - 202112
# 	<- response handled:	df.shape = (858, 47)	d_time:7.57
# 	-> send request		reporter_code = 70	202201 - 202212
# 	<- response handled:	df.shape = (938, 47)	d_time:11.86
# 	-> send request		reporter_code = 70	202301 - 202312
# 	<- response handled:	df.shape = (891, 47)	d_time:10.10
# Total null values: 7848
# 	-> send request		reporter_code = 222	201501 - 201512
# 	<- response handled:	df.shape = (366, 47)	d_time:5.12
# 	-> send request		reporter_code = 222	201601 - 201612
# 	<- response handled:	df.shape = (367, 47)	d_time:4.91
# 	-> send request		reporter_code = 222	201701 - 201712
# 	<- response handled:	df.shape = (420, 47)	d_time:4.01
# 	-> send request		reporter_code = 222	201801 - 201812
# 	-> send request		reporter_code = 222	201901 - 201912
# 	<- response handled:	df.shape = (442, 47)	d_time:4.26
# 	-> send request		reporter_code = 222	202001 - 202012
# 	<- response handled:	df.shape = (396, 47)	d_time:4.18
# 	-> send request		reporter_code = 222	202101 - 202112
# 	<- response handled:	df.shape = (402, 47)	d_time:4.96
# 	-> send request		reporter_code = 222	202201 - 202212
# 	<- response handled:	df.shape = (447, 47)	d_time:4.93
# 	-> send request		reporter_code = 222	202301 - 202312
# 	<- response handled:	df.shape = (392, 47)	d_time:4.61
# Total null values: 7752
# 	-> send request		reporter_code = 348	201501 - 201512
# 	<- response handled:	df.shape = (946, 47)	d_time:6.47
# 	-> send request		reporter_code = 348	201601 - 201612
# 	<- response handled:	df.shape = (1131, 47)	d_time:9.47
# 	-> send request		reporter_code = 348	201701 - 201712
# 	<- response handled:	df.shape = (1512, 47)	d_time:11.91
# 	-> send request		reporter_code = 348	201801 - 201812
# 	<- response handled:	df.shape = (1658, 47)	d_time:7.54
# 	-> send request		reporter_code = 348	201901 - 201912
# 	<- response handled:	df.shape = (1819, 47)	d_time:16.29
# 	-> send request		reporter_code = 348	202001 - 202012
# 	<- response handled:	df.shape = (1635, 47)	d_time:8.46
# 	-> send request		reporter_code = 348	202101 - 202112
# 	<- response handled:	df.shape = (1705, 47)	d_time:16.91
# 	-> send request		reporter_code = 348	202201 - 202212
# 	<- response handled:	df.shape = (1858, 47)	d_time:10.74
# 	-> send request		reporter_code = 348	202301 - 202312
# 	<- response handled:	df.shape = (2145, 47)	d_time:23.94
# Total null values: 7644
# 	-> send request		reporter_code = 120	201501 - 201512
# 	<- response handled:	df.shape = (448, 47)	d_time:8.26
# 	-> send request		reporter_code = 120	201601 - 201612
# 	<- response handled:	df.shape = (445, 47)	d_time:3.41
# 	-> send request		reporter_code = 120	201701 - 201712
# 	<- response handled:	df.shape = (498, 47)	d_time:4.05
# 	-> send request		reporter_code = 120	201801 - 201812
# 	<- response handled:	df.shape = (567, 47)	d_time:3.93
# 	-> send request		reporter_code = 120	201901 - 201912
# 	<- response handled:	df.shape = (608, 47)	d_time:5.46
# 	-> send request		reporter_code = 120	202001 - 202012
# 	<- response handled:	df.shape = (593, 47)	d_time:7.01
# 	-> send request		reporter_code = 120	202101 - 202112
# 	<- response handled:	df.shape = (546, 47)	d_time:7.49
# 	-> send request		reporter_code = 120	202201 - 202212
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 120	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# Total null values: 7560
# 	-> send request		reporter_code = 188	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 188	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 188	201701 - 201712
# 	<- response handled:	df.shape = (657, 47)	d_time:4.90
# 	-> send request		reporter_code = 188	201801 - 201812
# 	<- response handled:	df.shape = (668, 47)	d_time:4.79
# 	-> send request		reporter_code = 188	201901 - 201912
# 	<- response handled:	df.shape = (755, 47)	d_time:5.13
# 	-> send request		reporter_code = 188	202001 - 202012
# 	<- response handled:	df.shape = (617, 47)	d_time:7.58
# 	-> send request		reporter_code = 188	202101 - 202112
# 	<- response handled:	df.shape = (633, 47)	d_time:8.29
# 	-> send request		reporter_code = 188	202201 - 202212
# 	<- response handled:	df.shape = (611, 47)	d_time:7.46
# 	-> send request		reporter_code = 188	202301 - 202312
# 	<- response handled:	df.shape = (594, 47)	d_time:5.72
# Total null values: 7476
# 	-> send request		reporter_code = 188	201501 - 201512
# 	<- response handled:	df.shape = (580, 47)	d_time:6.21
# 	-> send request		reporter_code = 188	201601 - 201612
# 	<- response handled:	df.shape = (563, 47)	d_time:4.39
# Total null values: 7452
# 	-> send request		reporter_code = 887	201501 - 201512
# 	<- response handled:	df.shape = (221, 47)	d_time:3.56
# 	-> send request		reporter_code = 887	201601 - 201612
# 	<- response handled:	df.shape = (300, 47)	d_time:4.59
# 	-> send request		reporter_code = 887	201701 - 201712
# 	<- response handled:	df.shape = (386, 47)	d_time:3.35
# 	-> send request		reporter_code = 887	201801 - 201812
# 	<- response handled:	df.shape = (395, 47)	d_time:3.26
# 	-> send request		reporter_code = 887	201901 - 201912
# 	<- response handled:	df.shape = (474, 47)	d_time:4.28
# 	-> send request		reporter_code = 887	202001 - 202012
# 	<- response handled:	df.shape = (361, 47)	d_time:4.08
# 	-> send request		reporter_code = 887	202101 - 202112
# 	<- response handled:	df.shape = (360, 47)	d_time:3.39
# 	-> send request		reporter_code = 887	202201 - 202212
# 	<- response handled:	df.shape = (375, 47)	d_time:4.16
# 	-> send request		reporter_code = 887	202301 - 202312
# 	<- response handled:	df.shape = (321, 47)	d_time:13.10
# Total null values: 7344
# 	-> send request		reporter_code = 854	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 854	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 854	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 854	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 854	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 854	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 854	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 854	202201 - 202212
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 854	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# Total null values: 7344
# 	-> send request		reporter_code = 854	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 854	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 854	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 854	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 854	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 854	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 854	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 854	202201 - 202212
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 854	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# Total null values: 7344
# 	-> send request		reporter_code = 854	201501 - 201512
# 	<- response handled:	df.shape = (371, 47)	d_time:3.13
# 	-> send request		reporter_code = 854	201601 - 201612
# 	<- response handled:	df.shape = (367, 47)	d_time:3.17
# 	-> send request		reporter_code = 854	201701 - 201712
# 	<- response handled:	df.shape = (457, 47)	d_time:3.18
# 	-> send request		reporter_code = 854	201801 - 201812
# 	<- response handled:	df.shape = (467, 47)	d_time:3.20
# 	-> send request		reporter_code = 854	201901 - 201912
# 	<- response handled:	df.shape = (541, 47)	d_time:3.30
# 	-> send request		reporter_code = 854	202001 - 202012
# 	<- response handled:	df.shape = (373, 47)	d_time:3.24
# 	-> send request		reporter_code = 854	202101 - 202112
# 	<- response handled:	df.shape = (455, 47)	d_time:7.04
# 	-> send request		reporter_code = 854	202201 - 202212
# 	<- response handled:	df.shape = (471, 47)	d_time:3.91
# 	-> send request		reporter_code = 854	202301 - 202312
# 	<- response handled:	df.shape = (449, 47)	d_time:3.91
# Total null values: 7236
# 	-> send request		reporter_code = 800	201501 - 201512
# 	<- response handled:	df.shape = (267, 47)	d_time:3.86
# 	-> send request		reporter_code = 800	201601 - 201612
# 	<- response handled:	df.shape = (279, 47)	d_time:5.69
# 	-> send request		reporter_code = 800	201701 - 201712
# 	<- response handled:	df.shape = (494, 47)	d_time:4.22
# 	-> send request		reporter_code = 800	201801 - 201812
# 	<- response handled:	df.shape = (501, 47)	d_time:4.21
# 	-> send request		reporter_code = 800	201901 - 201912
# 	<- response handled:	df.shape = (495, 47)	d_time:5.14
# 	-> send request		reporter_code = 800	202001 - 202012
# 	<- response handled:	df.shape = (507, 47)	d_time:7.78
# 	-> send request		reporter_code = 800	202101 - 202112
# 	<- response handled:	df.shape = (503, 47)	d_time:4.48
# 	-> send request		reporter_code = 800	202201 - 202212
# 	<- response handled:	df.shape = (657, 47)	d_time:4.58
# 	-> send request		reporter_code = 800	202301 - 202312
# 	<- response handled:	df.shape = (499, 47)	d_time:4.07
# Total null values: 7128
# 	-> send request		reporter_code = 352	201501 - 201512
# 	<- response handled:	df.shape = (450, 47)	d_time:6.62
# 	-> send request		reporter_code = 352	201601 - 201612
# 	<- response handled:	df.shape = (451, 47)	d_time:4.05
# 	-> send request		reporter_code = 352	201701 - 201712
# 	<- response handled:	df.shape = (643, 47)	d_time:4.36
# 	-> send request		reporter_code = 352	201801 - 201812
# 	<- response handled:	df.shape = (729, 47)	d_time:4.78
# 	-> send request		reporter_code = 352	201901 - 201912
# 	<- response handled:	df.shape = (722, 47)	d_time:4.58
# 	-> send request		reporter_code = 352	202001 - 202012
# 	<- response handled:	df.shape = (595, 47)	d_time:5.12
# 	-> send request		reporter_code = 352	202101 - 202112
# 	<- response handled:	df.shape = (593, 47)	d_time:7.68
# 	-> send request		reporter_code = 352	202201 - 202212
# 	<- response handled:	df.shape = (661, 47)	d_time:8.42
# 	-> send request		reporter_code = 352	202301 - 202312
# 	<- response handled:	df.shape = (594, 47)	d_time:6.18
# Total null values: 7020
# 	-> send request		reporter_code = 388	201501 - 201512
# 	<- response handled:	df.shape = (229, 47)	d_time:3.63
# 	-> send request		reporter_code = 388	201601 - 201612
# 	<- response handled:	df.shape = (284, 47)	d_time:3.38
# 	-> send request		reporter_code = 388	201701 - 201712
# 	<- response handled:	df.shape = (274, 47)	d_time:3.41
# 	-> send request		reporter_code = 388	201801 - 201812
# 	<- response handled:	df.shape = (365, 47)	d_time:3.64
# 	-> send request		reporter_code = 388	201901 - 201912
# 	<- response handled:	df.shape = (379, 47)	d_time:3.99
# 	-> send request		reporter_code = 388	202001 - 202012
# 	<- response handled:	df.shape = (366, 47)	d_time:3.57
# 	-> send request		reporter_code = 388	202101 - 202112
# 	<- response handled:	df.shape = (366, 47)	d_time:3.71
# 	-> send request		reporter_code = 388	202201 - 202212
# 	<- response handled:	df.shape = (382, 47)	d_time:3.91
# 	-> send request		reporter_code = 388	202301 - 202312
# 	<- response handled:	df.shape = (348, 47)	d_time:4.29
# Total null values: 6912
# 	-> send request		reporter_code = 428	201501 - 201512
# 	<- response handled:	df.shape = (796, 47)	d_time:5.72
# 	-> send request		reporter_code = 428	201601 - 201612
# 	<- response handled:	df.shape = (765, 47)	d_time:5.20
# 	-> send request		reporter_code = 428	201701 - 201712
# 	<- response handled:	df.shape = (1077, 47)	d_time:5.76
# 	-> send request		reporter_code = 428	201801 - 201812
# 	<- response handled:	df.shape = (1293, 47)	d_time:6.69
# 	-> send request		reporter_code = 428	201901 - 201912
# 	<- response handled:	df.shape = (1350, 47)	d_time:6.76
# 	-> send request		reporter_code = 428	202001 - 202012
# 	<- response handled:	df.shape = (1326, 47)	d_time:9.75
# 	-> send request		reporter_code = 428	202101 - 202112
# 	<- response handled:	df.shape = (1293, 47)	d_time:12.26
# 	-> send request		reporter_code = 428	202201 - 202212
# 	<- response handled:	df.shape = (1519, 47)	d_time:6.45
# 	-> send request		reporter_code = 428	202301 - 202312
# 	<- response handled:	df.shape = (1417, 47)	d_time:11.95
# Total null values: 6804
# 	-> send request		reporter_code = 100	201501 - 201512
# 	<- response handled:	df.shape = (1023, 47)	d_time:4.88
# 	-> send request		reporter_code = 100	201601 - 201612
# 	<- response handled:	df.shape = (1006, 47)	d_time:7.32
# 	-> send request		reporter_code = 100	201701 - 201712
# 	<- response handled:	df.shape = (1472, 47)	d_time:8.80
# 	-> send request		reporter_code = 100	201801 - 201812
# 	<- response handled:	df.shape = (1454, 47)	d_time:7.48
# 	-> send request		reporter_code = 100	201901 - 201912
# 	<- response handled:	df.shape = (1624, 47)	d_time:15.83
# 	-> send request		reporter_code = 100	202001 - 202012
# 	<- response handled:	df.shape = (1618, 47)	d_time:7.27
# 	-> send request		reporter_code = 100	202101 - 202112
# 	<- response handled:	df.shape = (1547, 47)	d_time:14.83
# 	-> send request		reporter_code = 100	202201 - 202212
# 	<- response handled:	df.shape = (1684, 47)	d_time:8.00
# 	-> send request		reporter_code = 100	202301 - 202312
# 	<- response handled:	df.shape = (2266, 47)	d_time:16.01
# Total null values: 6696
# 	-> send request		reporter_code = 860	201501 - 201512
# 	<- response handled:	df.shape = (568, 47)	d_time:4.57
# 	-> send request		reporter_code = 860	201601 - 201612
# 	<- response handled:	df.shape = (611, 47)	d_time:4.04
# 	-> send request		reporter_code = 860	201701 - 201712
# 	<- response handled:	df.shape = (684, 47)	d_time:4.08
# 	-> send request		reporter_code = 860	201801 - 201812
# 	<- response handled:	df.shape = (896, 47)	d_time:4.17
# 	-> send request		reporter_code = 860	201901 - 201912
# 	<- response handled:	df.shape = (1089, 47)	d_time:3.97
# 	-> send request		reporter_code = 860	202001 - 202012
# 	<- response handled:	df.shape = (908, 47)	d_time:5.93
# 	-> send request		reporter_code = 860	202101 - 202112
# 	<- response handled:	df.shape = (842, 47)	d_time:6.00
# 	-> send request		reporter_code = 860	202201 - 202212
# 	<- response handled:	df.shape = (913, 47)	d_time:7.75
# 	-> send request		reporter_code = 860	202301 - 202312
# 	<- response handled:	df.shape = (982, 47)	d_time:4.74
# Total null values: 6588
# 	-> send request		reporter_code = 418	201501 - 201512
# 	<- response handled:	df.shape = (84, 47)	d_time:3.62
# 	-> send request		reporter_code = 418	201601 - 201612
# 	<- response handled:	df.shape = (101, 47)	d_time:3.02
# 	-> send request		reporter_code = 418	201701 - 201712
# 	<- response handled:	df.shape = (120, 47)	d_time:5.19
# 	-> send request		reporter_code = 418	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 418	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 418	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 418	202101 - 202112
# 	<- response handled:	df.shape = (88, 47)	d_time:5.95
# 	-> send request		reporter_code = 418	202201 - 202212
# 	<- response handled:	df.shape = (126, 47)	d_time:3.89
# 	-> send request		reporter_code = 418	202301 - 202312
# 	<- response handled:	df.shape = (95, 47)	d_time:3.46
# Total null values: 6516
# 	-> send request		reporter_code = 807	201501 - 201512
# 	<- response handled:	df.shape = (537, 47)	d_time:4.90
# 	-> send request		reporter_code = 807	201601 - 201612
# 	<- response handled:	df.shape = (546, 47)	d_time:7.56
# 	-> send request		reporter_code = 807	201701 - 201712
# 	<- response handled:	df.shape = (1124, 47)	d_time:5.50
# 	-> send request		reporter_code = 807	201801 - 201812
# 	<- response handled:	df.shape = (818, 47)	d_time:5.77
# 	-> send request		reporter_code = 807	201901 - 201912
# 	<- response handled:	df.shape = (983, 47)	d_time:5.77
# 	-> send request		reporter_code = 807	202001 - 202012
# 	<- response handled:	df.shape = (834, 47)	d_time:10.35
# 	-> send request		reporter_code = 807	202101 - 202112
# 	<- response handled:	df.shape = (851, 47)	d_time:9.56
# 	-> send request		reporter_code = 807	202201 - 202212
# 	<- response handled:	df.shape = (876, 47)	d_time:11.81
# 	-> send request		reporter_code = 807	202301 - 202312
# 	<- response handled:	df.shape = (849, 47)	d_time:8.36
# Total null values: 6408
# 	-> send request		reporter_code = 780	201501 - 201512
# 	<- response handled:	df.shape = (266, 47)	d_time:3.84
# 	-> send request		reporter_code = 780	201601 - 201612
# 	<- response handled:	df.shape = (331, 47)	d_time:3.91
# 	-> send request		reporter_code = 780	201701 - 201712
# 	<- response handled:	df.shape = (429, 47)	d_time:3.80
# 	-> send request		reporter_code = 780	201801 - 201812
# 	<- response handled:	df.shape = (402, 47)	d_time:5.73
# 	-> send request		reporter_code = 780	201901 - 201912
# 	<- response handled:	df.shape = (383, 47)	d_time:4.93
# 	-> send request		reporter_code = 780	202001 - 202012
# 	<- response handled:	df.shape = (384, 47)	d_time:3.96
# 	-> send request		reporter_code = 780	202101 - 202112
# 	<- response handled:	df.shape = (351, 47)	d_time:5.59
# 	-> send request		reporter_code = 780	202201 - 202212
# 	<- response handled:	df.shape = (364, 47)	d_time:4.66
# 	-> send request		reporter_code = 780	202301 - 202312
# 	<- response handled:	df.shape = (316, 47)	d_time:4.96
# Total null values: 6300
# 	-> send request		reporter_code = 688	201501 - 201512
# 	<- response handled:	df.shape = (762, 47)	d_time:10.90
# 	-> send request		reporter_code = 688	201601 - 201612
# 	<- response handled:	df.shape = (934, 47)	d_time:8.15
# 	-> send request		reporter_code = 688	201701 - 201712
# 	<- response handled:	df.shape = (1295, 47)	d_time:8.38
# 	-> send request		reporter_code = 688	201801 - 201812
# 	<- response handled:	df.shape = (1460, 47)	d_time:8.30
# 	-> send request		reporter_code = 688	201901 - 201912
# 	<- response handled:	df.shape = (1480, 47)	d_time:8.48
# 	-> send request		reporter_code = 688	202001 - 202012
# 	<- response handled:	df.shape = (1333, 47)	d_time:11.27
# 	-> send request		reporter_code = 688	202101 - 202112
# 	<- response handled:	df.shape = (1406, 47)	d_time:16.13
# 	-> send request		reporter_code = 688	202201 - 202212
# 	<- response handled:	df.shape = (1459, 47)	d_time:12.93
# 	-> send request		reporter_code = 688	202301 - 202312
# 	<- response handled:	df.shape = (1379, 47)	d_time:16.23
# Total null values: 6192
# 	-> send request		reporter_code = 818	201501 - 201512
# 	<- response handled:	df.shape = (867, 47)	d_time:7.52
# 	-> send request		reporter_code = 818	201601 - 201612
# 	<- response handled:	df.shape = (945, 47)	d_time:6.23
# 	-> send request		reporter_code = 818	201701 - 201712
# 	<- response handled:	df.shape = (1194, 47)	d_time:7.70
# 	-> send request		reporter_code = 818	201801 - 201812
# 	<- response handled:	df.shape = (1283, 47)	d_time:6.88
# 	-> send request		reporter_code = 818	201901 - 201912
# 	<- response handled:	df.shape = (1407, 47)	d_time:9.08
# 	-> send request		reporter_code = 818	202001 - 202012
# 	<- response handled:	df.shape = (1096, 47)	d_time:7.30
# 	-> send request		reporter_code = 818	202101 - 202112
# 	<- response handled:	df.shape = (1203, 47)	d_time:8.00
# 	-> send request		reporter_code = 818	202201 - 202212
# 	<- response handled:	df.shape = (1276, 47)	d_time:14.86
# 	-> send request		reporter_code = 818	202301 - 202312
# 	<- response handled:	df.shape = (1098, 47)	d_time:9.72
# Total null values: 6084
# 	-> send request		reporter_code = 450	201501 - 201512
# 	<- response handled:	df.shape = (199, 47)	d_time:4.19
# 	-> send request		reporter_code = 450	201601 - 201612
# 	<- response handled:	df.shape = (260, 47)	d_time:4.72
# 	-> send request		reporter_code = 450	201701 - 201712
# 	<- response handled:	df.shape = (268, 47)	d_time:4.48
# 	-> send request		reporter_code = 450	201801 - 201812
# 	<- response handled:	df.shape = (307, 47)	d_time:4.13
# 	-> send request		reporter_code = 450	201901 - 201912
# 	<- response handled:	df.shape = (346, 47)	d_time:5.40
# 	-> send request		reporter_code = 450	202001 - 202012
# 	<- response handled:	df.shape = (340, 47)	d_time:4.76
# 	-> send request		reporter_code = 450	202101 - 202112
# 	<- response handled:	df.shape = (305, 47)	d_time:5.75
# 	-> send request		reporter_code = 450	202201 - 202212
# 	<- response handled:	df.shape = (397, 47)	d_time:6.64
# 	-> send request		reporter_code = 450	202301 - 202312
# 	<- response handled:	df.shape = (313, 47)	d_time:5.16
# Total null values: 5976
# 	-> send request		reporter_code = 894	201501 - 201512
# 	<- response handled:	df.shape = (161, 47)	d_time:4.19
# 	-> send request		reporter_code = 894	201601 - 201612
# 	<- response handled:	df.shape = (197, 47)	d_time:3.79
# 	-> send request		reporter_code = 894	201701 - 201712
# 	<- response handled:	df.shape = (277, 47)	d_time:3.51
# 	-> send request		reporter_code = 894	201801 - 201812
# 	<- response handled:	df.shape = (277, 47)	d_time:4.72
# 	-> send request		reporter_code = 894	201901 - 201912
# 	<- response handled:	df.shape = (350, 47)	d_time:4.82
# 	-> send request		reporter_code = 894	202001 - 202012
# 	<- response handled:	df.shape = (330, 47)	d_time:4.05
# 	-> send request		reporter_code = 894	202101 - 202112
# 	<- response handled:	df.shape = (318, 47)	d_time:5.08
# 	-> send request		reporter_code = 894	202201 - 202212
# 	<- response handled:	df.shape = (384, 47)	d_time:4.65
# 	-> send request		reporter_code = 894	202301 - 202312
# 	<- response handled:	df.shape = (302, 47)	d_time:4.15
# Total null values: 5868
# 	-> send request		reporter_code = 598	201501 - 201512
# 	<- response handled:	df.shape = (108, 47)	d_time:3.75
# 	-> send request		reporter_code = 598	201601 - 201612
# 	<- response handled:	df.shape = (121, 47)	d_time:3.42
# 	-> send request		reporter_code = 598	201701 - 201712
# 	<- response handled:	df.shape = (168, 47)	d_time:3.96
# 	-> send request		reporter_code = 598	201801 - 201812
# 	<- response handled:	df.shape = (161, 47)	d_time:4.33
# 	-> send request		reporter_code = 598	201901 - 201912
# 	<- response handled:	df.shape = (163, 47)	d_time:3.87
# 	-> send request		reporter_code = 598	202001 - 202012
# 	<- response handled:	df.shape = (145, 47)	d_time:3.37
# 	-> send request		reporter_code = 598	202101 - 202112
# 	<- response handled:	df.shape = (102, 47)	d_time:3.89
# 	-> send request		reporter_code = 598	202201 - 202212
# 	<- response handled:	df.shape = (125, 47)	d_time:5.64
# 	-> send request		reporter_code = 598	202301 - 202312
# 	<- response handled:	df.shape = (112, 47)	d_time:3.48
# Total null values: 5760
# 	-> send request		reporter_code = 440	201501 - 201512
# 	<- response handled:	df.shape = (903, 47)	d_time:7.33
# 	-> send request		reporter_code = 440	201601 - 201612
# 	<- response handled:	df.shape = (937, 47)	d_time:6.21
# 	-> send request		reporter_code = 440	201701 - 201712
# 	<- response handled:	df.shape = (1304, 47)	d_time:10.00
# 	-> send request		reporter_code = 440	201801 - 201812
# 	<- response handled:	df.shape = (1487, 47)	d_time:8.05
# 	-> send request		reporter_code = 440	201901 - 201912
# 	<- response handled:	df.shape = (1657, 47)	d_time:8.95
# 	-> send request		reporter_code = 440	202001 - 202012
# 	<- response handled:	df.shape = (1461, 47)	d_time:5.36
# 	-> send request		reporter_code = 440	202101 - 202112
# 	-> send request		reporter_code = 440	202201 - 202212
# 	<- response handled:	df.shape = (1706, 47)	d_time:8.77
# 	-> send request		reporter_code = 440	202301 - 202312
# 	<- response handled:	df.shape = (1599, 47)	d_time:15.45
# Total null values: 5664
# 	-> send request		reporter_code = 328	201501 - 201512
# 	<- response handled:	df.shape = (140, 47)	d_time:3.73
# 	-> send request		reporter_code = 328	201601 - 201612
# 	<- response handled:	df.shape = (168, 47)	d_time:4.60
# 	-> send request		reporter_code = 328	201701 - 201712
# 	<- response handled:	df.shape = (191, 47)	d_time:5.18
# 	-> send request		reporter_code = 328	201801 - 201812
# 	<- response handled:	df.shape = (150, 47)	d_time:4.96
# 	-> send request		reporter_code = 328	201901 - 201912
# 	<- response handled:	df.shape = (228, 47)	d_time:4.07
# 	-> send request		reporter_code = 328	202001 - 202012
# 	<- response handled:	df.shape = (198, 47)	d_time:3.91
# 	-> send request		reporter_code = 328	202101 - 202112
# 	<- response handled:	df.shape = (263, 47)	d_time:4.41
# 	-> send request		reporter_code = 328	202201 - 202212
# 	<- response handled:	df.shape = (240, 47)	d_time:5.80
# 	-> send request		reporter_code = 328	202301 - 202312
# 	<- response handled:	df.shape = (220, 47)	d_time:3.70
# Total null values: 5556
# 	-> send request		reporter_code = 558	201501 - 201512
# 	<- response handled:	df.shape = (253, 47)	d_time:5.11
# 	-> send request		reporter_code = 558	201601 - 201612
# 	<- response handled:	df.shape = (266, 47)	d_time:4.12
# 	-> send request		reporter_code = 558	201701 - 201712
# 	<- response handled:	df.shape = (307, 47)	d_time:3.95
# 	-> send request		reporter_code = 558	201801 - 201812
# 	<- response handled:	df.shape = (290, 47)	d_time:3.54
# 	-> send request		reporter_code = 558	201901 - 201912
# 	<- response handled:	df.shape = (463, 47)	d_time:3.83
# 	-> send request		reporter_code = 558	202001 - 202012
# 	<- response handled:	df.shape = (425, 47)	d_time:4.92
# 	-> send request		reporter_code = 558	202101 - 202112
# 	<- response handled:	df.shape = (348, 47)	d_time:5.98
# 	-> send request		reporter_code = 558	202201 - 202212
# 	<- response handled:	df.shape = (377, 47)	d_time:4.34
# 	-> send request		reporter_code = 558	202301 - 202312
# 	<- response handled:	df.shape = (379, 47)	d_time:4.97
# Total null values: 5448
# 	-> send request		reporter_code = 498	201501 - 201512
# 	<- response handled:	df.shape = (531, 47)	d_time:6.61
# 	-> send request		reporter_code = 498	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 498	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 498	201801 - 201812
# 	<- response handled:	df.shape = (839, 47)	d_time:4.34
# 	-> send request		reporter_code = 498	201901 - 201912
# 	<- response handled:	df.shape = (960, 47)	d_time:5.42
# 	-> send request		reporter_code = 498	202001 - 202012
# 	<- response handled:	df.shape = (845, 47)	d_time:6.29
# 	-> send request		reporter_code = 498	202101 - 202112
# 	<- response handled:	df.shape = (900, 47)	d_time:8.61
# 	-> send request		reporter_code = 498	202201 - 202212
# 	<- response handled:	df.shape = (955, 47)	d_time:13.29
# 	-> send request		reporter_code = 498	202301 - 202312
# 	<- response handled:	df.shape = (1188, 47)	d_time:9.56
# Total null values: 5364
# 	-> send request		reporter_code = 268	201501 - 201512
# 	<- response handled:	df.shape = (650, 47)	d_time:4.68
# 	-> send request		reporter_code = 268	201601 - 201612
# 	<- response handled:	df.shape = (741, 47)	d_time:4.26
# 	-> send request		reporter_code = 268	201701 - 201712
# 	<- response handled:	df.shape = (972, 47)	d_time:5.21
# 	-> send request		reporter_code = 268	201801 - 201812
# 	<- response handled:	df.shape = (1127, 47)	d_time:4.93
# 	-> send request		reporter_code = 268	201901 - 201912
# 	<- response handled:	df.shape = (1149, 47)	d_time:4.99
# 	-> send request		reporter_code = 268	202001 - 202012
# 	<- response handled:	df.shape = (1052, 47)	d_time:7.44
# 	-> send request		reporter_code = 268	202101 - 202112
# 	<- response handled:	df.shape = (1113, 47)	d_time:6.00
# 	-> send request		reporter_code = 268	202201 - 202212
# 	<- response handled:	df.shape = (1197, 47)	d_time:8.41
# 	-> send request		reporter_code = 268	202301 - 202312
# 	<- response handled:	df.shape = (1121, 47)	d_time:6.03
# Total null values: 5256
# 	-> send request		reporter_code = 4	201501 - 201512
# 	<- response handled:	df.shape = (326, 47)	d_time:3.21
# 	-> send request		reporter_code = 4	201601 - 201612
# 	<- response handled:	df.shape = (334, 47)	d_time:4.26
# 	-> send request		reporter_code = 4	201701 - 201712
# 	<- response handled:	df.shape = (429, 47)	d_time:3.99
# 	-> send request		reporter_code = 4	201801 - 201812
# 	<- response handled:	df.shape = (524, 47)	d_time:4.58
# 	-> send request		reporter_code = 4	201901 - 201912
# 	<- response handled:	df.shape = (477, 47)	d_time:3.61
# 	-> send request		reporter_code = 4	202001 - 202012
# 	<- response handled:	df.shape = (503, 47)	d_time:3.94
# 	-> send request		reporter_code = 4	202101 - 202112
# 	<- response handled:	df.shape = (313, 47)	d_time:3.75
# 	-> send request		reporter_code = 4	202201 - 202212
# 	<- response handled:	df.shape = (202, 47)	d_time:4.86
# 	-> send request		reporter_code = 4	202301 - 202312
# 	<- response handled:	df.shape = (203, 47)	d_time:3.91
# Total null values: 5148
# 	-> send request		reporter_code = 44	201501 - 201512
# 	<- response handled:	df.shape = (361, 47)	d_time:3.44
# 	-> send request		reporter_code = 44	201601 - 201612
# 	<- response handled:	df.shape = (368, 47)	d_time:3.87
# 	-> send request		reporter_code = 44	201701 - 201712
# 	<- response handled:	df.shape = (403, 47)	d_time:4.89
# 	-> send request		reporter_code = 44	201801 - 201812
# 	<- response handled:	df.shape = (435, 47)	d_time:4.19
# 	-> send request		reporter_code = 44	201901 - 201912
# 	<- response handled:	df.shape = (459, 47)	d_time:5.92
# 	-> send request		reporter_code = 44	202001 - 202012
# 	<- response handled:	df.shape = (355, 47)	d_time:5.45
# 	-> send request		reporter_code = 44	202101 - 202112
# 	<- response handled:	df.shape = (299, 47)	d_time:3.74
# 	-> send request		reporter_code = 44	202201 - 202212
# 	<- response handled:	df.shape = (345, 47)	d_time:4.06
# 	-> send request		reporter_code = 44	202301 - 202312
# 	<- response handled:	df.shape = (234, 47)	d_time:4.03
# Total null values: 5040
# 	-> send request		reporter_code = 398	201501 - 201512
# 	<- response handled:	df.shape = (732, 47)	d_time:6.13
# 	-> send request		reporter_code = 398	201601 - 201612
# 	<- response handled:	df.shape = (798, 47)	d_time:5.11
# 	-> send request		reporter_code = 398	201701 - 201712
# 	<- response handled:	df.shape = (1029, 47)	d_time:4.91
# 	-> send request		reporter_code = 398	201801 - 201812
# 	<- response handled:	df.shape = (1069, 47)	d_time:7.49
# 	-> send request		reporter_code = 398	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 398	202001 - 202012
# 	<- response handled:	df.shape = (1050, 47)	d_time:5.14
# 	-> send request		reporter_code = 398	202101 - 202112
# 	<- response handled:	df.shape = (992, 47)	d_time:6.14
# 	-> send request		reporter_code = 398	202201 - 202212
# 	<- response handled:	df.shape = (1196, 47)	d_time:8.29
# 	-> send request		reporter_code = 398	202301 - 202312
# 	<- response handled:	df.shape = (1276, 47)	d_time:11.51
# Total null values: 4944
# 	-> send request		reporter_code = 703	201501 - 201512
# 	<- response handled:	df.shape = (714, 47)	d_time:6.78
# 	-> send request		reporter_code = 703	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 703	201701 - 201712
# 	<- response handled:	df.shape = (1116, 47)	d_time:9.44
# 	-> send request		reporter_code = 703	201801 - 201812
# 	<- response handled:	df.shape = (1252, 47)	d_time:4.80
# 	-> send request		reporter_code = 703	201901 - 201912
# 	<- response handled:	df.shape = (1379, 47)	d_time:10.00
# 	-> send request		reporter_code = 703	202001 - 202012
# 	<- response handled:	df.shape = (1354, 47)	d_time:5.98
# 	-> send request		reporter_code = 703	202101 - 202112
# 	<- response handled:	df.shape = (1410, 47)	d_time:17.52
# 	-> send request		reporter_code = 703	202201 - 202212
# 	<- response handled:	df.shape = (1449, 47)	d_time:8.16
# 	-> send request		reporter_code = 703	202301 - 202312
# 	<- response handled:	df.shape = (1402, 47)	d_time:16.59
# Total null values: 4848
# 	-> send request		reporter_code = 417	201501 - 201512
# 	<- response handled:	df.shape = (427, 47)	d_time:3.78
# 	-> send request		reporter_code = 417	201601 - 201612
# 	<- response handled:	df.shape = (420, 47)	d_time:6.33
# 	-> send request		reporter_code = 417	201701 - 201712
# 	<- response handled:	df.shape = (467, 47)	d_time:4.39
# 	-> send request		reporter_code = 417	201801 - 201812
# 	<- response handled:	df.shape = (480, 47)	d_time:4.11
# 	-> send request		reporter_code = 417	201901 - 201912
# 	<- response handled:	df.shape = (499, 47)	d_time:3.58
# 	-> send request		reporter_code = 417	202001 - 202012
# 	<- response handled:	df.shape = (473, 47)	d_time:4.30
# 	-> send request		reporter_code = 417	202101 - 202112
# 	<- response handled:	df.shape = (462, 47)	d_time:4.55
# 	-> send request		reporter_code = 417	202201 - 202212
# 	<- response handled:	df.shape = (577, 47)	d_time:4.80
# 	-> send request		reporter_code = 417	202301 - 202312
# 	<- response handled:	df.shape = (888, 47)	d_time:5.43
# Total null values: 4740
# 	-> send request		reporter_code = 275	201501 - 201512
# 	<- response handled:	df.shape = (259, 47)	d_time:3.06
# 	-> send request		reporter_code = 275	201601 - 201612
# 	<- response handled:	df.shape = (295, 47)	d_time:3.90
# 	-> send request		reporter_code = 275	201701 - 201712
# 	<- response handled:	df.shape = (327, 47)	d_time:3.62
# 	-> send request		reporter_code = 275	201801 - 201812
# 	<- response handled:	df.shape = (302, 47)	d_time:3.81
# 	-> send request		reporter_code = 275	201901 - 201912
# 	<- response handled:	df.shape = (307, 47)	d_time:3.83
# 	-> send request		reporter_code = 275	202001 - 202012
# 	<- response handled:	df.shape = (283, 47)	d_time:8.85
# 	-> send request		reporter_code = 275	202101 - 202112
# 	<- response handled:	df.shape = (321, 47)	d_time:7.51
# 	-> send request		reporter_code = 275	202201 - 202212
# 	<- response handled:	df.shape = (297, 47)	d_time:4.54
# 	-> send request		reporter_code = 275	202301 - 202312
# 	<- response handled:	df.shape = (230, 47)	d_time:4.86
# Total null values: 4632
# 	-> send request		reporter_code = 646	201501 - 201512
# 	<- response handled:	df.shape = (91, 47)	d_time:3.96
# 	-> send request		reporter_code = 646	201601 - 201612
# 	<- response handled:	df.shape = (143, 47)	d_time:4.67
# 	-> send request		reporter_code = 646	201701 - 201712
# 	<- response handled:	df.shape = (127, 47)	d_time:3.57
# 	-> send request		reporter_code = 646	201801 - 201812
# 	<- response handled:	df.shape = (181, 47)	d_time:4.52
# 	-> send request		reporter_code = 646	201901 - 201912
# 	<- response handled:	df.shape = (205, 47)	d_time:3.29
# 	-> send request		reporter_code = 646	202001 - 202012
# 	<- response handled:	df.shape = (132, 47)	d_time:4.46
# 	-> send request		reporter_code = 646	202101 - 202112
# 	<- response handled:	df.shape = (181, 47)	d_time:4.03
# 	-> send request		reporter_code = 646	202201 - 202212
# 	<- response handled:	df.shape = (226, 47)	d_time:6.29
# 	-> send request		reporter_code = 646	202301 - 202312
# 	<- response handled:	df.shape = (224, 47)	d_time:3.94
# Total null values: 4524
# 	-> send request		reporter_code = 682	201501 - 201512
# 	<- response handled:	df.shape = (816, 47)	d_time:6.82
# 	-> send request		reporter_code = 682	201601 - 201612
# 	<- response handled:	df.shape = (874, 47)	d_time:6.08
# 	-> send request		reporter_code = 682	201701 - 201712
# 	<- response handled:	df.shape = (1183, 47)	d_time:8.95
# 	-> send request		reporter_code = 682	201801 - 201812
# 	<- response handled:	df.shape = (1165, 47)	d_time:6.70
# 	-> send request		reporter_code = 682	201901 - 201912
# 	<- response handled:	df.shape = (1167, 47)	d_time:7.39
# 	-> send request		reporter_code = 682	202001 - 202012
# 	<- response handled:	df.shape = (984, 47)	d_time:8.08
# 	-> send request		reporter_code = 682	202101 - 202112
# 	<- response handled:	df.shape = (1097, 47)	d_time:7.31
# 	-> send request		reporter_code = 682	202201 - 202212
# 	-> send request		reporter_code = 682	202301 - 202312
# 	<- response handled:	df.shape = (1103, 47)	d_time:10.01
# Total null values: 4428
# 	-> send request		reporter_code = 204	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 204	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 204	201701 - 201712
# 	<- response handled:	df.shape = (243, 47)	d_time:3.42
# 	-> send request		reporter_code = 204	201801 - 201812
# 	<- response handled:	df.shape = (268, 47)	d_time:3.35
# 	-> send request		reporter_code = 204	201901 - 201912
# 	<- response handled:	df.shape = (298, 47)	d_time:3.92
# 	-> send request		reporter_code = 204	202001 - 202012
# 	<- response handled:	df.shape = (188, 47)	d_time:4.27
# 	-> send request		reporter_code = 204	202101 - 202112
# 	<- response handled:	df.shape = (210, 47)	d_time:3.76
# 	-> send request		reporter_code = 204	202201 - 202212
# 	<- response handled:	df.shape = (275, 47)	d_time:6.61
# 	-> send request		reporter_code = 204	202301 - 202312
# 	<- response handled:	df.shape = (229, 47)	d_time:3.61
# Total null values: 4344
# 	-> send request		reporter_code = 204	201501 - 201512
# 	<- response handled:	df.shape = (244, 47)	d_time:4.90
# 	-> send request		reporter_code = 204	201601 - 201612
# 	<- response handled:	df.shape = (245, 47)	d_time:4.88
# Total null values: 4320
# 	-> send request		reporter_code = 52	201501 - 201512
# 	<- response handled:	df.shape = (209, 47)	d_time:3.93
# 	-> send request		reporter_code = 52	201601 - 201612
# Enter new subscription key:  9f1492872e0c48e4849fe94ab8cd1332
# 	-> send request		reporter_code = 52	201701 - 201712
# 	-> send request		reporter_code = 52	201801 - 201812
# 	<- response handled:	df.shape = (299, 47)	d_time:5.24
# 	-> send request		reporter_code = 52	201901 - 201912
# 	<- response handled:	df.shape = (355, 47)	d_time:9.91
# 	-> send request		reporter_code = 52	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 6 seconds.'}
# 	-> send request		reporter_code = 52	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 52	202201 - 202212
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 52	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# Total null values: 4284
# 	-> send request		reporter_code = 762	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 762	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 762	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 762	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 762	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 762	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 762	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 762	202201 - 202212
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 762	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# Total null values: 4284
# 	-> send request		reporter_code = 762	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 762	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 762	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 762	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 762	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 762	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 762	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 762	202201 - 202212
# 	<- response handled:	df.shape = (395, 47)	d_time:3.64
# 	-> send request		reporter_code = 762	202301 - 202312
# 	<- response handled:	df.shape = (409, 47)	d_time:4.26
# Total null values: 4260
# 	-> send request		reporter_code = 762	201501 - 201512
# 	<- response handled:	df.shape = (344, 47)	d_time:3.63
# 	-> send request		reporter_code = 762	201601 - 201612
# 	<- response handled:	df.shape = (357, 47)	d_time:3.76
# 	-> send request		reporter_code = 762	201701 - 201712
# 	<- response handled:	df.shape = (407, 47)	d_time:3.48
# 	-> send request		reporter_code = 762	201801 - 201812
# 	<- response handled:	df.shape = (479, 47)	d_time:3.48
# 	-> send request		reporter_code = 762	201901 - 201912
# 	<- response handled:	df.shape = (486, 47)	d_time:3.56
# 	-> send request		reporter_code = 762	202001 - 202012
# 	<- response handled:	df.shape = (373, 47)	d_time:3.94
# 	-> send request		reporter_code = 762	202101 - 202112
# 	<- response handled:	df.shape = (421, 47)	d_time:3.83
# Total null values: 4176
# 	-> send request		reporter_code = 31	201501 - 201512
# 	<- response handled:	df.shape = (741, 47)	d_time:5.02
# 	-> send request		reporter_code = 31	201601 - 201612
# 	<- response handled:	df.shape = (755, 47)	d_time:4.03
# 	-> send request		reporter_code = 31	201701 - 201712
# 	<- response handled:	df.shape = (905, 47)	d_time:4.54
# 	-> send request		reporter_code = 31	201801 - 201812
# 	<- response handled:	df.shape = (954, 47)	d_time:5.06
# 	-> send request		reporter_code = 31	201901 - 201912
# 	<- response handled:	df.shape = (1005, 47)	d_time:5.39
# 	-> send request		reporter_code = 31	202001 - 202012
# 	<- response handled:	df.shape = (840, 47)	d_time:5.33
# 	-> send request		reporter_code = 31	202101 - 202112
# 	<- response handled:	df.shape = (770, 47)	d_time:6.39
# 	-> send request		reporter_code = 31	202201 - 202212
# 	<- response handled:	df.shape = (924, 47)	d_time:6.59
# 	-> send request		reporter_code = 31	202301 - 202312
# 	<- response handled:	df.shape = (777, 47)	d_time:6.17
# Total null values: 4068
# 	-> send request		reporter_code = 499	201501 - 201512
# 	<- response handled:	df.shape = (413, 47)	d_time:5.87
# 	-> send request		reporter_code = 499	201601 - 201612
# 	<- response handled:	df.shape = (446, 47)	d_time:3.85
# 	-> send request		reporter_code = 499	201701 - 201712
# 	<- response handled:	df.shape = (647, 47)	d_time:4.45
# 	-> send request		reporter_code = 499	201801 - 201812
# 	<- response handled:	df.shape = (738, 47)	d_time:4.13
# 	-> send request		reporter_code = 499	201901 - 201912
# 	<- response handled:	df.shape = (698, 47)	d_time:4.31
# 	-> send request		reporter_code = 499	202001 - 202012
# 	<- response handled:	df.shape = (672, 47)	d_time:4.37
# 	-> send request		reporter_code = 499	202101 - 202112
# 	<- response handled:	df.shape = (681, 47)	d_time:5.19
# 	-> send request		reporter_code = 499	202201 - 202212
# 	<- response handled:	df.shape = (708, 47)	d_time:5.80
# 	-> send request		reporter_code = 499	202301 - 202312
# 	<- response handled:	df.shape = (651, 47)	d_time:5.74
# Total null values: 3960
# 	-> send request		reporter_code = 180	201501 - 201512
# 	<- response handled:	df.shape = (428, 47)	d_time:4.68
# 	-> send request		reporter_code = 180	201601 - 201612
# 	<- response handled:	df.shape = (501, 47)	d_time:4.58
# 	-> send request		reporter_code = 180	201701 - 201712
# 	<- response handled:	df.shape = (468, 47)	d_time:4.70
# 	-> send request		reporter_code = 180	201801 - 201812
# 	<- response handled:	df.shape = (566, 47)	d_time:5.30
# 	-> send request		reporter_code = 180	201901 - 201912
# 	<- response handled:	df.shape = (627, 47)	d_time:5.25
# 	-> send request		reporter_code = 180	202001 - 202012
# 	<- response handled:	df.shape = (509, 47)	d_time:5.57
# 	-> send request		reporter_code = 180	202101 - 202112
# 	<- response handled:	df.shape = (501, 47)	d_time:5.04
# 	-> send request		reporter_code = 180	202201 - 202212
# 	-> send request		reporter_code = 180	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# Total null values: 3876
# 	-> send request		reporter_code = 96	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 96	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 5 seconds.'}
# 	-> send request		reporter_code = 96	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 96	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 96	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 4 seconds.'}
# 	-> send request		reporter_code = 96	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 96	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 96	202201 - 202212
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 3 seconds.'}
# 	-> send request		reporter_code = 96	202301 - 202312
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# Total null values: 3876
# 	-> send request		reporter_code = 96	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 96	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 96	201701 - 201712
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 2 seconds.'}
# 	-> send request		reporter_code = 96	201801 - 201812
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 96	201901 - 201912
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 96	202001 - 202012
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 96	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 96	202201 - 202212
# 	<- response handled:	df.shape = (244, 47)	d_time:4.27
# ...
# 	<- response handled:	df.shape = (113, 47)	d_time:3.62
# 	-> send request		reporter_code = 462	201601 - 201612
# 	<- response handled:	df.shape = (140, 47)	d_time:3.35
# 	-> send request		reporter_code = 462	201701 - 201712
# 	<- response handled:	df.shape = (263, 47)	d_time:3.33
# 	-> send request		reporter_code = 462	201801 - 201812
# 	<- response handled:	df.shape = (284, 47)	d_time:3.72
# 	-> send request		reporter_code = 462	201901 - 201912
# 	<- response handled:	df.shape = (221, 47)	d_time:3.46
# 	-> send request		reporter_code = 462	202001 - 202012
# 	<- response handled:	df.shape = (207, 47)	d_time:3.12
# 	-> send request		reporter_code = 462	202101 - 202112
# 	<- response handled:	df.shape = (235, 47)	d_time:3.63
# 	-> send request		reporter_code = 462	202201 - 202212
# 	<- response handled:	df.shape = (291, 47)	d_time:4.25
# 	-> send request		reporter_code = 462	202301 - 202312
# 	<- response handled:	df.shape = (282, 47)	d_time:3.65
# Total null values: 1440
# 	-> send request		reporter_code = 562	201501 - 201512
# 	<- response handled:	df.shape = (160, 47)	d_time:3.02
# 	-> send request		reporter_code = 562	201601 - 201612
# 	<- response handled:	df.shape = (149, 47)	d_time:3.03
# 	-> send request		reporter_code = 562	201701 - 201712
# 	<- response handled:	df.shape = (188, 47)	d_time:3.26
# 	-> send request		reporter_code = 562	201801 - 201812
# 	<- response handled:	df.shape = (144, 47)	d_time:3.05
# 	-> send request		reporter_code = 562	201901 - 201912
# 	<- response handled:	df.shape = (250, 47)	d_time:3.92
# 	-> send request		reporter_code = 562	202001 - 202012
# 	<- response handled:	df.shape = (142, 47)	d_time:3.24
# 	-> send request		reporter_code = 562	202101 - 202112
# 	<- response handled:	df.shape = (190, 47)	d_time:3.25
# 	-> send request		reporter_code = 562	202201 - 202212
# 	<- response handled:	df.shape = (229, 47)	d_time:3.71
# 	-> send request		reporter_code = 562	202301 - 202312
# 	<- response handled:	df.shape = (160, 47)	d_time:3.25
# Total null values: 1332
# 	-> send request		reporter_code = 710	201501 - 201512
# 	<- response handled:	df.shape = (943, 47)	d_time:5.58
# 	-> send request		reporter_code = 710	201601 - 201612
# 	<- response handled:	df.shape = (1177, 47)	d_time:9.15
# 	-> send request		reporter_code = 710	201701 - 201712
# 	<- response handled:	df.shape = (1429, 47)	d_time:15.22
# 	-> send request		reporter_code = 710	201801 - 201812
# 	<- response handled:	df.shape = (1457, 47)	d_time:6.07
# 	-> send request		reporter_code = 710	201901 - 201912
# 	<- response handled:	df.shape = (1551, 47)	d_time:13.26
# 	-> send request		reporter_code = 710	202001 - 202012
# 	<- response handled:	df.shape = (1267, 47)	d_time:7.44
# 	-> send request		reporter_code = 710	202101 - 202112
# 	<- response handled:	df.shape = (1222, 47)	d_time:13.58
# 	-> send request		reporter_code = 710	202201 - 202212
# 	<- response handled:	df.shape = (1338, 47)	d_time:9.66
# 	-> send request		reporter_code = 710	202301 - 202312
# 	<- response handled:	df.shape = (1198, 47)	d_time:6.91
# Total null values: 1224
# 	-> send request		reporter_code = 178	201501 - 201512
# 	<- response handled:	df.shape = (301, 47)	d_time:3.73
# 	-> send request		reporter_code = 178	201601 - 201612
# 	<- response handled:	df.shape = (451, 47)	d_time:3.17
# 	-> send request		reporter_code = 178	201701 - 201712
# 	<- response handled:	df.shape = (391, 47)	d_time:3.83
# 	-> send request		reporter_code = 178	201801 - 201812
# 	<- response handled:	df.shape = (396, 47)	d_time:3.31
# 	-> send request		reporter_code = 178	201901 - 201912
# 	<- response handled:	df.shape = (366, 47)	d_time:3.71
# 	-> send request		reporter_code = 178	202001 - 202012
# 	<- response handled:	df.shape = (153, 47)	d_time:4.94
# 	-> send request		reporter_code = 178	202101 - 202112
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 178	202201 - 202212
# 	<- response handled:	df.shape = (308, 47)	d_time:4.16
# 	-> send request		reporter_code = 178	202301 - 202312
# 	<- response handled:	df.shape = (328, 47)	d_time:5.48
# Total null values: 1128
# 	-> send request		reporter_code = 768	201501 - 201512
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 768	201601 - 201612
# {'statusCode': 429, 'message': 'Rate limit is exceeded. Try again in 1 seconds.'}
# 	-> send request		reporter_code = 768	201701 - 201712
# 	<- response handled:	df.shape = (513, 47)	d_time:4.79
# 	-> send request		reporter_code = 768	201801 - 201812
# 	<- response handled:	df.shape = (523, 47)	d_time:3.37
# 	-> send request		reporter_code = 768	201901 - 201912
# 	<- response handled:	df.shape = (592, 47)	d_time:4.26
# 	-> send request		reporter_code = 768	202001 - 202012
# 	<- response handled:	df.shape = (472, 47)	d_time:4.78
# 	-> send request		reporter_code = 768	202101 - 202112
# 	<- response handled:	df.shape = (474, 47)	d_time:5.46
# 	-> send request		reporter_code = 768	202201 - 202212
# 	<- response handled:	df.shape = (504, 47)	d_time:4.96
# 	-> send request		reporter_code = 768	202301 - 202312
# 	<- response handled:	df.shape = (432, 47)	d_time:4.11
# Total null values: 1044
# 	-> send request		reporter_code = 768	201501 - 201512
# 	<- response handled:	df.shape = (488, 47)	d_time:3.72
# 	-> send request		reporter_code = 768	201601 - 201612
# 	<- response handled:	df.shape = (465, 47)	d_time:3.62
# Total null values: 1020
# 	-> send request		reporter_code = 384	201501 - 201512
# 	<- response handled:	df.shape = (610, 47)	d_time:4.33
# 	-> send request		reporter_code = 384	201601 - 201612
# 	<- response handled:	df.shape = (544, 47)	d_time:3.85
# 	-> send request		reporter_code = 384	201701 - 201712
# 	<- response handled:	df.shape = (619, 47)	d_time:4.01
# 	-> send request		reporter_code = 384	201801 - 201812
# 	<- response handled:	df.shape = (668, 47)	d_time:6.97
# 	-> send request		reporter_code = 384	201901 - 201912
# 	<- response handled:	df.shape = (762, 47)	d_time:4.41
# 	-> send request		reporter_code = 384	202001 - 202012
# 	<- response handled:	df.shape = (678, 47)	d_time:4.80
# 	-> send request		reporter_code = 384	202101 - 202112
# 	<- response handled:	df.shape = (728, 47)	d_time:5.16
# 	-> send request		reporter_code = 384	202201 - 202212
# 	<- response handled:	df.shape = (805, 47)	d_time:5.61
# 	-> send request		reporter_code = 384	202301 - 202312
# 	<- response handled:	df.shape = (764, 47)	d_time:5.20
# Total null values: 912
# 	-> send request		reporter_code = 662	201501 - 201512
# 	<- response handled:	df.shape = (84, 47)	d_time:4.60
# 	-> send request		reporter_code = 662	201601 - 201612
# 	<- response handled:	df.shape = (74, 47)	d_time:3.26
# 	-> send request		reporter_code = 662	201701 - 201712
# 	<- response handled:	df.shape = (102, 47)	d_time:2.90
# 	-> send request		reporter_code = 662	201801 - 201812
# 	<- response handled:	df.shape = (80, 47)	d_time:3.61
# 	-> send request		reporter_code = 662	201901 - 201912
# 	<- response handled:	df.shape = (67, 47)	d_time:3.49
# 	-> send request		reporter_code = 662	202001 - 202012
# 	<- response handled:	df.shape = (121, 47)	d_time:2.98
# 	-> send request		reporter_code = 662	202101 - 202112
# 	<- response handled:	df.shape = (118, 47)	d_time:3.93
# 	-> send request		reporter_code = 662	202201 - 202212
# 	<- response handled:	df.shape = (112, 47)	d_time:3.40
# 	-> send request		reporter_code = 662	202301 - 202312
# 	<- response handled:	df.shape = (117, 47)	d_time:3.43
# Total null values: 804
# 	-> send request		reporter_code = 308	201501 - 201512
# 	<- response handled:	df.shape = (79, 47)	d_time:3.16
# 	-> send request		reporter_code = 308	201601 - 201612
# 	<- response handled:	df.shape = (91, 47)	d_time:2.95
# 	-> send request		reporter_code = 308	201701 - 201712
# 	<- response handled:	df.shape = (119, 47)	d_time:3.15
# 	-> send request		reporter_code = 308	201801 - 201812
# 	<- response handled:	df.shape = (87, 47)	d_time:5.25
# 	-> send request		reporter_code = 308	201901 - 201912
# 	<- response handled:	df.shape = (88, 47)	d_time:3.25
# 	-> send request		reporter_code = 308	202001 - 202012
# 	<- response handled:	df.shape = (96, 47)	d_time:3.46
# 	-> send request		reporter_code = 308	202101 - 202112
# 	<- response handled:	df.shape = (89, 47)	d_time:3.07
# 	-> send request		reporter_code = 308	202201 - 202212
# 	<- response handled:	df.shape = (89, 47)	d_time:3.48
# 	-> send request		reporter_code = 308	202301 - 202312
# 	<- response handled:	df.shape = (85, 47)	d_time:3.28
# Total null values: 696
# 	-> send request		reporter_code = 140	201501 - 201512
# 	<- response handled:	df.shape = (26, 47)	d_time:2.89
# 	-> send request		reporter_code = 140	201601 - 201612
# 	<- response handled:	df.shape = (76, 47)	d_time:2.97
# 	-> send request		reporter_code = 140	201701 - 201712
# 	<- response handled:	df.shape = (108, 47)	d_time:3.18
# 	-> send request		reporter_code = 140	201801 - 201812
# 	<- response handled:	df.shape = (132, 47)	d_time:2.77
# 	-> send request		reporter_code = 140	201901 - 201912
# 	<- response handled:	df.shape = (141, 47)	d_time:3.00
# 	-> send request		reporter_code = 140	202001 - 202012
# 	<- response handled:	df.shape = (100, 47)	d_time:2.93
# 	-> send request		reporter_code = 140	202101 - 202112
# 	<- response handled:	df.shape = (84, 47)	d_time:3.87
# 	-> send request		reporter_code = 140	202201 - 202212
# 	<- response handled:	df.shape = (93, 47)	d_time:3.34
# 	-> send request		reporter_code = 140	202301 - 202312
# 	<- response handled:	df.shape = (48, 47)	d_time:3.12
# Total null values: 588
# 	-> send request		reporter_code = 690	201501 - 201512
# 	<- response handled:	df.shape = (181, 47)	d_time:3.43
# 	-> send request		reporter_code = 690	201601 - 201612
# 	<- response handled:	df.shape = (261, 47)	d_time:4.05
# 	-> send request		reporter_code = 690	201701 - 201712
# 	<- response handled:	df.shape = (353, 47)	d_time:3.85
# 	-> send request		reporter_code = 690	201801 - 201812
# 	<- response handled:	df.shape = (376, 47)	d_time:4.25
# 	-> send request		reporter_code = 690	201901 - 201912
# 	-> send request		reporter_code = 690	202001 - 202012
# 	<- response handled:	df.shape = (278, 47)	d_time:4.17
# 	-> send request		reporter_code = 690	202101 - 202112
# 	<- response handled:	df.shape = (249, 47)	d_time:3.68
# 	-> send request		reporter_code = 690	202201 - 202212
# 	<- response handled:	df.shape = (377, 47)	d_time:4.55
# 	-> send request		reporter_code = 690	202301 - 202312
# 	<- response handled:	df.shape = (303, 47)	d_time:4.06
# Total null values: 492
# 	-> send request		reporter_code = 498	201601 - 201612
# 	<- response handled:	df.shape = (548, 47)	d_time:4.19
# 	-> send request		reporter_code = 498	201701 - 201712
# 	<- response handled:	df.shape = (733, 47)	d_time:4.26
# Total null values: 468
# 	-> send request		reporter_code = 703	201601 - 201612
# 	<- response handled:	df.shape = (796, 47)	d_time:7.43
# Total null values: 456
# 	-> send request		reporter_code = 52	201601 - 201612
# 	<- response handled:	df.shape = (167, 47)	d_time:3.48
# 	-> send request		reporter_code = 52	201701 - 201712
# 	<- response handled:	df.shape = (259, 47)	d_time:3.17
# 	-> send request		reporter_code = 52	202001 - 202012
# 	<- response handled:	df.shape = (314, 47)	d_time:5.94
# 	-> send request		reporter_code = 52	202101 - 202112
# 	<- response handled:	df.shape = (306, 47)	d_time:4.44
# 	-> send request		reporter_code = 52	202201 - 202212
# 	<- response handled:	df.shape = (335, 47)	d_time:4.51
# 	-> send request		reporter_code = 52	202301 - 202312
# 	<- response handled:	df.shape = (281, 47)	d_time:4.29
# Total null values: 384
# 	-> send request		reporter_code = 222	201801 - 201812
# 	<- response handled:	df.shape = (396, 47)	d_time:4.49
# Total null values: 372
# 	-> send request		reporter_code = 418	201801 - 201812
# 	<- response handled:	df.shape = (115, 47)	d_time:3.99
# 	-> send request		reporter_code = 418	201901 - 201912
# 	-> send request		reporter_code = 418	202001 - 202012
# 	<- response handled:	df.shape = (86, 47)	d_time:3.26
# Total null values: 348
# 	-> send request		reporter_code = 704	201901 - 201912
# 	<- response handled:	df.shape = (1124, 47)	d_time:11.31
# Total null values: 336
# 	-> send request		reporter_code = 418	201901 - 201912
# 	<- response handled:	df.shape = (118, 47)	d_time:3.45
# Total null values: 324
# 	-> send request		reporter_code = 398	201901 - 201912
# 	<- response handled:	df.shape = (1178, 47)	d_time:4.76
# Total null values: 312
# 	-> send request		reporter_code = 690	201901 - 201912
# 	<- response handled:	df.shape = (389, 47)	d_time:4.43
# Total null values: 300
# 	-> send request		reporter_code = 156	202001 - 202012
# 	-> send request		reporter_code = 156	202101 - 202112
# 	<- response handled:	df.shape = (1596, 47)	d_time:26.70
# 	-> send request		reporter_code = 156	202201 - 202212
# 	<- response handled:	df.shape = (1619, 47)	d_time:32.80
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 276
# 	-> send request		reporter_code = 156	202001 - 202012
# 	<- response handled:	df.shape = (1677, 47)	d_time:24.42
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 264
# 	-> send request		reporter_code = 591	202001 - 202012
# 	<- response handled:	df.shape = (1003, 47)	d_time:5.72
# Total null values: 252
# 	-> send request		reporter_code = 8	202001 - 202012
# 	<- response handled:	df.shape = (915, 47)	d_time:5.04
# 	-> send request		reporter_code = 8	202101 - 202112
# 	<- response handled:	df.shape = (946, 47)	d_time:6.12
# 	-> send request		reporter_code = 8	202201 - 202212
# 	<- response handled:	df.shape = (976, 47)	d_time:7.38
# 	-> send request		reporter_code = 8	202301 - 202312
# 	<- response handled:	df.shape = (914, 47)	d_time:6.84
# Total null values: 204
# 	-> send request		reporter_code = 36	202101 - 202112
# 	<- response handled:	df.shape = (1014, 47)	d_time:11.93
# Total null values: 192
# 	-> send request		reporter_code = 380	202101 - 202112
# 	<- response handled:	df.shape = (2280, 47)	d_time:40.85
# Total null values: 180
# 	-> send request		reporter_code = 686	202101 - 202112
# 	<- response handled:	df.shape = (732, 47)	d_time:5.24
# Total null values: 168
# 	-> send request		reporter_code = 642	202101 - 202112
# 	<- response handled:	df.shape = (1828, 47)	d_time:15.63
# 	-> send request		reporter_code = 642	202301 - 202312
# 	<- response handled:	df.shape = (1725, 47)	d_time:17.80
# Total null values: 144
# 	-> send request		reporter_code = 440	202101 - 202112
# 	<- response handled:	df.shape = (1560, 47)	d_time:13.15
# Total null values: 132
# 	-> send request		reporter_code = 178	202101 - 202112
# 	<- response handled:	df.shape = (218, 47)	d_time:5.33
# Total null values: 120
# 	-> send request		reporter_code = 120	202201 - 202212
# 	<- response handled:	df.shape = (626, 47)	d_time:4.69
# 	-> send request		reporter_code = 120	202301 - 202312
# 	<- response handled:	df.shape = (482, 47)	d_time:4.20
# Total null values: 96
# 	-> send request		reporter_code = 682	202201 - 202212
# 	<- response handled:	df.shape = (1109, 47)	d_time:8.10
# Total null values: 84
# 	-> send request		reporter_code = 180	202201 - 202212
# 	<- response handled:	df.shape = (598, 47)	d_time:5.70
# 	-> send request		reporter_code = 180	202301 - 202312
# 	<- response handled:	df.shape = (516, 47)	d_time:4.42
# Total null values: 60
# 	-> send request		reporter_code = 276	202301 - 202312
# 	<- response handled:	df.shape = (2433, 47)	d_time:56.82
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# Total null values: 48
# 	-> send request		reporter_code = 156	202301 - 202312
# 	<- response handled:	df.shape = (1492, 47)	d_time:56.92
# Total null values: 36
# 	-> send request		reporter_code = 144	202301 - 202312
# 	<- response handled:	df.shape = (449, 47)	d_time:8.39
# Total null values: 24
# 	-> send request		reporter_code = 340	202301 - 202312
# 	<- response handled:	df.shape = (472, 47)	d_time:4.66
# Total null values: 12
# 	-> send request		reporter_code = 643	202301 - 202312
# 	<- response handled:	df.shape = (653, 47)	d_time:10.55

# %%
mirror_data[~mirror_data.mirrorPrimaryValue.isna()]
# Out:
#        period  reporterCode  \
# 0      201501           842
# 1      201502           842
# 2      201503           842
# 3      201504           842
# 4      201505           842
# ...       ...           ...
# 16195  202308           690
# 16196  202309           690
# 16197  202310           690
# 16198  202311           690
# 16199  202312           690
#
#                                       mirrorPrimaryValue  \
# 0      {32: 20.0, 36: 14213.961, 40: 6345.066, 56: 47...
# 1      {352: 144687.791, 360: 2780.0, 372: 10427.245,...
# 2      {604: 9238106.87, 579: 22806402.843, 191: 3798...
# 3      {251: 32264324.748, 56: 51408687.716, 76: 753....
# 4      {76: 1060607.0, 276: 4850852.1, 152: 50.0, 40:...
# ...                                                  ...
# 16195  {191: 4672.0, 480: 1520.005, 699: 37439.329, 7...
# 16196  {191: 2659.0, 480: 1636.697, 620: 11386.804, 6...
# 16197  {156: 48000.0, 191: 4508.0, 450: 26889.777, 48...
# 16198  {450: 781.246, 480: 26442.854, 528: 1459.111, ...
# 16199  {56: 1537.232, 191: 8995.0, 276: 42497.918, 34...
#
#                                             mirrorNetWgt
# 0      {32: 31.2, 36: 0.0, 40: 0.0, 56: 121257385.254...
# 1      {352: 203952.0, 360: 2813.176, 372: 5407.426, ...
# 2      {604: 13515588.0, 579: 54169094.0, 191: 1002.0...
# 3      {251: 0.0, 56: 120008979.77, 76: 21.0, 724: 77...
# 4      {76: 2623903.223, 276: 1331880.0, 152: 1.42, 4...
# ...                                                  ...
# 16195  {191: 1045.0, 480: 228.0, 699: 12357.0, 710: 2...
# 16196  {191: 344.0, 480: 450.0, 620: 2119.0, 699: 45....
# 16197  {156: 50000.0, 191: 1121.11, 450: 18124.2, 480...
# 16198  {450: 484.27, 480: 18286.0, 528: 441.0, 699: 5...
# 16199  {56: 149.87, 191: 1918.61, 276: 7742.0, 348: 1...
#
# [16200 rows x 4 columns]

# %%
mirror_data
# Out:
#        period  reporterCode  \
# 0      201501           842
# 1      201502           842
# 2      201503           842
# 3      201504           842
# 4      201505           842
# ...       ...           ...
# 16195  202308           690
# 16196  202309           690
# 16197  202310           690
# 16198  202311           690
# 16199  202312           690
#
#                                       mirrorPrimaryValue  \
# 0      {32: 20.0, 36: 14213.961, 40: 6345.066, 56: 47...
# 1      {352: 144687.791, 360: 2780.0, 372: 10427.245,...
# 2      {604: 9238106.87, 579: 22806402.843, 191: 3798...
# 3      {251: 32264324.748, 56: 51408687.716, 76: 753....
# 4      {76: 1060607.0, 276: 4850852.1, 152: 50.0, 40:...
# ...                                                  ...
# 16195  {191: 4672.0, 480: 1520.005, 699: 37439.329, 7...
# 16196  {191: 2659.0, 480: 1636.697, 620: 11386.804, 6...
# 16197  {156: 48000.0, 191: 4508.0, 450: 26889.777, 48...
# 16198  {450: 781.246, 480: 26442.854, 528: 1459.111, ...
# 16199  {56: 1537.232, 191: 8995.0, 276: 42497.918, 34...
#
#                                             mirrorNetWgt
# 0      {32: 31.2, 36: 0.0, 40: 0.0, 56: 121257385.254...
# 1      {352: 203952.0, 360: 2813.176, 372: 5407.426, ...
# 2      {604: 13515588.0, 579: 54169094.0, 191: 1002.0...
# 3      {251: 0.0, 56: 120008979.77, 76: 21.0, 724: 77...
# 4      {76: 2623903.223, 276: 1331880.0, 152: 1.42, 4...
# ...                                                  ...
# 16195  {191: 1045.0, 480: 228.0, 699: 12357.0, 710: 2...
# 16196  {191: 344.0, 480: 450.0, 620: 2119.0, 699: 45....
# 16197  {156: 50000.0, 191: 1121.11, 450: 18124.2, 480...
# 16198  {450: 484.27, 480: 18286.0, 528: 441.0, 699: 5...
# 16199  {56: 149.87, 191: 1918.61, 276: 7742.0, 348: 1...
#
# [16200 rows x 4 columns]

# %%
mirror_data.to_csv(f'graph data mirrored imp - {hs_code}.csv')

# %% [markdown]
# # Обьединяем статистику и зеркальную статистику

# %%
data.period = data.period.astype('str')
data.reporterCode = data.reporterCode.astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10950 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   period        10950 non-null  object
#  1   reporterCode  10950 non-null  int64
#  2   primaryValue  10950 non-null  object
#  3   netWgt        10950 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 427.7+ KB

# %%
mirror_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16200 entries, 0 to 16199
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   period              16200 non-null  object
#  1   reporterCode        16200 non-null  int64
#  2   mirrorPrimaryValue  16200 non-null  object
#  3   mirrorNetWgt        16200 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 632.8+ KB

# %%
result = mirror_data\
    .merge(data, on=['period', 'reporterCode'], how='left') \
    .fillna('{}') # Тогда точно получим данные зеркальной статистики

# %%
result
# Out:
#        period  reporterCode  \
# 0      201501           842
# 1      201502           842
# 2      201503           842
# 3      201504           842
# 4      201505           842
# ...       ...           ...
# 16195  202308           690
# 16196  202309           690
# 16197  202310           690
# 16198  202311           690
# 16199  202312           690
#
#                                       mirrorPrimaryValue  \
# 0      {32: 20.0, 36: 14213.961, 40: 6345.066, 56: 47...
# 1      {352: 144687.791, 360: 2780.0, 372: 10427.245,...
# 2      {604: 9238106.87, 579: 22806402.843, 191: 3798...
# 3      {251: 32264324.748, 56: 51408687.716, 76: 753....
# 4      {76: 1060607.0, 276: 4850852.1, 152: 50.0, 40:...
# ...                                                  ...
# 16195  {191: 4672.0, 480: 1520.005, 699: 37439.329, 7...
# 16196  {191: 2659.0, 480: 1636.697, 620: 11386.804, 6...
# 16197  {156: 48000.0, 191: 4508.0, 450: 26889.777, 48...
# 16198  {450: 781.246, 480: 26442.854, 528: 1459.111, ...
# 16199  {56: 1537.232, 191: 8995.0, 276: 42497.918, 34...
#
#                                             mirrorNetWgt  \
# 0      {32: 31.2, 36: 0.0, 40: 0.0, 56: 121257385.254...
# 1      {352: 203952.0, 360: 2813.176, 372: 5407.426, ...
# 2      {604: 13515588.0, 579: 54169094.0, 191: 1002.0...
# 3      {251: 0.0, 56: 120008979.77, 76: 21.0, 724: 77...
# 4      {76: 2623903.223, 276: 1331880.0, 152: 1.42, 4...
# ...                                                  ...
# 16195  {191: 1045.0, 480: 228.0, 699: 12357.0, 710: 2...
# 16196  {191: 344.0, 480: 450.0, 620: 2119.0, 699: 45....
# 16197  {156: 50000.0, 191: 1121.11, 450: 18124.2, 480...
# 16198  {450: 484.27, 480: 18286.0, 528: 441.0, 699: 5...
# 16199  {56: 149.87, 191: 1918.61, 276: 7742.0, 348: 1...
#
#                                             primaryValue  \
# 0      {124: 413074932.0, 484: 562456657.0, 826: 1478...
# 1      {124: 440461875.0, 410: 1943779.0, 344: 833824...
# 2      {484: 496613044.0, 36: 4395521.0, 251: 8787662...
# 3      {156: 15464840.0, 344: 608236.0, 490: 2053497....
# 4      {410: 45811982.0, 76: 218399444.0, 214: 695832...
# ...                                                  ...
# 16195                                                 {}
# 16196                                                 {}
# 16197                                                 {}
# 16198                                                 {}
# 16199                                                 {}
#
#                                                   netWgt
# 0      {124: 0.0, 484: 0.0, 826: 0.0, 156: 0.0, 392: ...
# 1      {124: 0.0, 410: 0.0, 344: 0.0, 784: 0.0, 376: ...
# 2      {484: 0.0, 36: 0.0, 251: 0.0, 152: 0.0, 591: 0...
# 3      {156: 0.0, 344: 0.0, 490: 0.0, 188: 0.0, 604: ...
# 4      {410: 0.0, 76: 0.0, 214: 0.0, 764: 0.0, 724: 0...
# ...                                                  ...
# 16195                                                 {}
# 16196                                                 {}
# 16197                                                 {}
# 16198                                                 {}
# 16199                                                 {}
#
# [16200 rows x 6 columns]

# %% [markdown]
# # Сохраняем результат

# %%
result.to_csv(f'export and mirrored export top 150 {hs_code} 2015-2023.csv')
